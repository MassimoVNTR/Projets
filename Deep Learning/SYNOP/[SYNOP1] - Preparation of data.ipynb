# %% [markdown]
# # <!-- TITLE --> [SYNOP1] - Preparation of data
# <!-- DESC --> Episode 1 : Data analysis and preparation of a usuable meteorological dataset (SYNOP)
# <!-- AUTHOR : Jean-Luc Parouty (CNRS/SIMaP) -->
#
# ## Objectives :
#  - Undestand the data
#  - cleanup a usable dataset
#
#
# SYNOP meteorological data, can be found on :
# https://public.opendatasoft.com
#
# About SYNOP datasets :
# https://public.opendatasoft.com/explore/dataset/donnees-synop-essentielles-omm/information/?sort=date
#
# This dataset contains a set of measurements (temperature, pressure, ...) made every 3 hours at the LYS airport.
# The objective will be to predict the evolution of the weather !
#
# ## What we're going to do :
#
#  - Read the data
#  - Cleanup and build a usable dataset
#
# ## Step 1 - Import and init

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import TensorBoard

import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import h5py, json
import os,time,sys
import math, random

from importlib import reload

run_dir = './run/SYNOP'
datasets_dir = 'fidle-datasets'

pd.set_option('display.max_rows',200)

# %%
from IPython.display import Markdown
def subtitle(t):
    display(Markdown(f'<br>**{t}**'))

# %% [markdown]
# ## Step 2 - Parameters
# `output_dir` : where to save our enhanced dataset.
# ./data is a good choice because our dataset will be very small.

# %%
# ---- Our future enhanced dataset (no need to change)
#
dataset_filename     = 'synop-LYS.csv'
description_filename = 'synop.json'
output_dir           = './data'

# %% [markdown]
# ## Step 3 - Retrieve the dataset
# There are two parts to recover:
#  - The data itself (csv)
#  - Description of the data (json)

# %%
data_filename   = 'origine/donnees-synop-essentielles-omm-LYS.csv'
schema_filename = 'origine/schema.json'

# %% [markdown]
# ### 3.1 - Read dataset description
# We need the list and description of the columns.

# %%
with open(f'{datasets_dir}/SYNOP/{schema_filename}','r') as json_file:
    schema = json.load(json_file)

synop_codes=list( schema['definitions']['donnees-synop-essentielles-omm_records']['properties']['fields']['properties'].keys() )

# %% [markdown]
# ### 3.2 - Read data

# %%
df = pd.read_csv(f'{datasets_dir}/SYNOP/{data_filename}', header=0, sep=';')
subtitle('Raw data :')
display(df.tail(10))

# ---- Get the columns name as descriptions
synop_desc = list(df.columns)

# ---- Set Codes as columns name
df.columns   = synop_codes
code2desc    = dict(zip(synop_codes, synop_desc))

# ---- Count the na values by columns
columns_na = df.isna().sum().tolist()

# ---- Show all of that
df_desc=pd.DataFrame({'Code':synop_codes, 'Description':synop_desc, 'Na':columns_na})

subtitle('List of columns :')
display(df_desc.style.set_properties(**{'text-align': 'left'}))

print('Shape is : ', df.shape)
# Out:
# <br>**Raw data :**
#        ID OMM station                       Date  Pression au niveau mer  \
# 29155            7481  2019-11-16T01:00:00+01:00                100640.0
# 29156            7481  2019-11-16T19:00:00+01:00                101090.0
# 29157            7481  2020-02-12T16:00:00+01:00                102460.0
# 29158            7481  2020-02-13T04:00:00+01:00                102100.0
# 29159            7481  2020-02-14T01:00:00+01:00                102080.0
# 29160            7481  2020-02-14T07:00:00+01:00                102430.0
# 29161            7481  2020-02-15T16:00:00+01:00                102190.0
# 29162            7481  2020-01-25T22:00:00+01:00                102030.0
# 29163            7481  2020-01-26T19:00:00+01:00                102010.0
# 29164            7481  2020-02-08T19:00:00+01:00                102540.0
#
#        Variation de pression en 3 heures  Type de tendance barométrique  \
# 29155                              130.0                            1.0
# 29156                               90.0                            3.0
# 29157                             -180.0                            6.0
# 29158                             -240.0                            8.0
# 29159                              230.0                            1.0
# 29160                              210.0                            2.0
# 29161                             -160.0                            6.0
# 29162                               20.0                            1.0
# 29163                               80.0                            3.0
# 29164                              150.0                            2.0
#
#        Direction du vent moyen 10 mn  Vitesse du vent moyen 10 mn  \
# 29155                          190.0                          1.0
# 29156                          130.0                          3.5
# 29157                          360.0                          2.3
# 29158                          150.0                          4.9
# 29159                          280.0                          4.5
# 29160                          140.0                          3.4
# 29161                          180.0                          6.9
# 29162                          140.0                          4.9
# 29163                          170.0                          3.7
# 29164                          190.0                          6.2
#
#        Température  Point de rosée  Humidité  ...  Longitude  Latitude  \
# 29155       272.75          272.75     100.0  ...   5.077833   45.7265
# 29156       276.95          274.65      85.0  ...   5.077833   45.7265
# 29157       283.45          271.75      44.0  ...   5.077833   45.7265
# 29158       274.75          271.15      77.0  ...   5.077833   45.7265
# 29159       283.15          276.15      62.0  ...   5.077833   45.7265
# 29160       280.15          278.45      89.0  ...   5.077833   45.7265
# 29161       290.15          273.75      33.0  ...   5.077833   45.7265
# 29162       281.45          278.55      82.0  ...   5.077833   45.7265
# 29163       282.85          279.15      78.0  ...   5.077833   45.7265
# 29164       283.75          277.65      66.0  ...   5.077833   45.7265
#
#           communes (name)  communes (code)                  EPCI (name)  \
# 29155  Colombier-Saugnieu            69299  CC de l'Est Lyonnais (CCEL)
# 29156  Colombier-Saugnieu            69299  CC de l'Est Lyonnais (CCEL)
# 29157  Colombier-Saugnieu            69299  CC de l'Est Lyonnais (CCEL)
# 29158  Colombier-Saugnieu            69299  CC de l'Est Lyonnais (CCEL)
# 29159  Colombier-Saugnieu            69299  CC de l'Est Lyonnais (CCEL)
# 29160  Colombier-Saugnieu            69299  CC de l'Est Lyonnais (CCEL)
# 29161  Colombier-Saugnieu            69299  CC de l'Est Lyonnais (CCEL)
# 29162  Colombier-Saugnieu            69299  CC de l'Est Lyonnais (CCEL)
# 29163  Colombier-Saugnieu            69299  CC de l'Est Lyonnais (CCEL)
# 29164  Colombier-Saugnieu            69299  CC de l'Est Lyonnais (CCEL)
#
#        EPCI (code)  department (name)  department (code)  \
# 29155    246900575              Rhône                 69
# 29156    246900575              Rhône                 69
# 29157    246900575              Rhône                 69
# 29158    246900575              Rhône                 69
# 29159    246900575              Rhône                 69
# 29160    246900575              Rhône                 69
# 29161    246900575              Rhône                 69
# 29162    246900575              Rhône                 69
# 29163    246900575              Rhône                 69
# 29164    246900575              Rhône                 69
#
#               region (name)  region (code)
# 29155  Auvergne-Rhône-Alpes             84
# 29156  Auvergne-Rhône-Alpes             84
# 29157  Auvergne-Rhône-Alpes             84
# 29158  Auvergne-Rhône-Alpes             84
# 29159  Auvergne-Rhône-Alpes             84
# 29160  Auvergne-Rhône-Alpes             84
# 29161  Auvergne-Rhône-Alpes             84
# 29162  Auvergne-Rhône-Alpes             84
# 29163  Auvergne-Rhône-Alpes             84
# 29164  Auvergne-Rhône-Alpes             84
#
# [10 rows x 81 columns]
# <br>**List of columns :**
# <style type="text/css">
# #T_7cc04_row0_col0, #T_7cc04_row0_col1, #T_7cc04_row0_col2, #T_7cc04_row1_col0, #T_7cc04_row1_col1, #T_7cc04_row1_col2, #T_7cc04_row2_col0, #T_7cc04_row2_col1, #T_7cc04_row2_col2, #T_7cc04_row3_col0, #T_7cc04_row3_col1, #T_7cc04_row3_col2, #T_7cc04_row4_col0, #T_7cc04_row4_col1, #T_7cc04_row4_col2, #T_7cc04_row5_col0, #T_7cc04_row5_col1, #T_7cc04_row5_col2, #T_7cc04_row6_col0, #T_7cc04_row6_col1, #T_7cc04_row6_col2, #T_7cc04_row7_col0, #T_7cc04_row7_col1, #T_7cc04_row7_col2, #T_7cc04_row8_col0, #T_7cc04_row8_col1, #T_7cc04_row8_col2, #T_7cc04_row9_col0, #T_7cc04_row9_col1, #T_7cc04_row9_col2, #T_7cc04_row10_col0, #T_7cc04_row10_col1, #T_7cc04_row10_col2, #T_7cc04_row11_col0, #T_7cc04_row11_col1, #T_7cc04_row11_col2, #T_7cc04_row12_col0, #T_7cc04_row12_col1, #T_7cc04_row12_col2, #T_7cc04_row13_col0, #T_7cc04_row13_col1, #T_7cc04_row13_col2, #T_7cc04_row14_col0, #T_7cc04_row14_col1, #T_7cc04_row14_col2, #T_7cc04_row15_col0, #T_7cc04_row15_col1, #T_7cc04_row15_col2, #T_7cc04_row16_col0, #T_7cc04_row16_col1, #T_7cc04_row16_col2, #T_7cc04_row17_col0, #T_7cc04_row17_col1, #T_7cc04_row17_col2, #T_7cc04_row18_col0, #T_7cc04_row18_col1, #T_7cc04_row18_col2, #T_7cc04_row19_col0, #T_7cc04_row19_col1, #T_7cc04_row19_col2, #T_7cc04_row20_col0, #T_7cc04_row20_col1, #T_7cc04_row20_col2, #T_7cc04_row21_col0, #T_7cc04_row21_col1, #T_7cc04_row21_col2, #T_7cc04_row22_col0, #T_7cc04_row22_col1, #T_7cc04_row22_col2, #T_7cc04_row23_col0, #T_7cc04_row23_col1, #T_7cc04_row23_col2, #T_7cc04_row24_col0, #T_7cc04_row24_col1, #T_7cc04_row24_col2, #T_7cc04_row25_col0, #T_7cc04_row25_col1, #T_7cc04_row25_col2, #T_7cc04_row26_col0, #T_7cc04_row26_col1, #T_7cc04_row26_col2, #T_7cc04_row27_col0, #T_7cc04_row27_col1, #T_7cc04_row27_col2, #T_7cc04_row28_col0, #T_7cc04_row28_col1, #T_7cc04_row28_col2, #T_7cc04_row29_col0, #T_7cc04_row29_col1, #T_7cc04_row29_col2, #T_7cc04_row30_col0, #T_7cc04_row30_col1, #T_7cc04_row30_col2, #T_7cc04_row31_col0, #T_7cc04_row31_col1, #T_7cc04_row31_col2, #T_7cc04_row32_col0, #T_7cc04_row32_col1, #T_7cc04_row32_col2, #T_7cc04_row33_col0, #T_7cc04_row33_col1, #T_7cc04_row33_col2, #T_7cc04_row34_col0, #T_7cc04_row34_col1, #T_7cc04_row34_col2, #T_7cc04_row35_col0, #T_7cc04_row35_col1, #T_7cc04_row35_col2, #T_7cc04_row36_col0, #T_7cc04_row36_col1, #T_7cc04_row36_col2, #T_7cc04_row37_col0, #T_7cc04_row37_col1, #T_7cc04_row37_col2, #T_7cc04_row38_col0, #T_7cc04_row38_col1, #T_7cc04_row38_col2, #T_7cc04_row39_col0, #T_7cc04_row39_col1, #T_7cc04_row39_col2, #T_7cc04_row40_col0, #T_7cc04_row40_col1, #T_7cc04_row40_col2, #T_7cc04_row41_col0, #T_7cc04_row41_col1, #T_7cc04_row41_col2, #T_7cc04_row42_col0, #T_7cc04_row42_col1, #T_7cc04_row42_col2, #T_7cc04_row43_col0, #T_7cc04_row43_col1, #T_7cc04_row43_col2, #T_7cc04_row44_col0, #T_7cc04_row44_col1, #T_7cc04_row44_col2, #T_7cc04_row45_col0, #T_7cc04_row45_col1, #T_7cc04_row45_col2, #T_7cc04_row46_col0, #T_7cc04_row46_col1, #T_7cc04_row46_col2, #T_7cc04_row47_col0, #T_7cc04_row47_col1, #T_7cc04_row47_col2, #T_7cc04_row48_col0, #T_7cc04_row48_col1, #T_7cc04_row48_col2, #T_7cc04_row49_col0, #T_7cc04_row49_col1, #T_7cc04_row49_col2, #T_7cc04_row50_col0, #T_7cc04_row50_col1, #T_7cc04_row50_col2, #T_7cc04_row51_col0, #T_7cc04_row51_col1, #T_7cc04_row51_col2, #T_7cc04_row52_col0, #T_7cc04_row52_col1, #T_7cc04_row52_col2, #T_7cc04_row53_col0, #T_7cc04_row53_col1, #T_7cc04_row53_col2, #T_7cc04_row54_col0, #T_7cc04_row54_col1, #T_7cc04_row54_col2, #T_7cc04_row55_col0, #T_7cc04_row55_col1, #T_7cc04_row55_col2, #T_7cc04_row56_col0, #T_7cc04_row56_col1, #T_7cc04_row56_col2, #T_7cc04_row57_col0, #T_7cc04_row57_col1, #T_7cc04_row57_col2, #T_7cc04_row58_col0, #T_7cc04_row58_col1, #T_7cc04_row58_col2, #T_7cc04_row59_col0, #T_7cc04_row59_col1, #T_7cc04_row59_col2, #T_7cc04_row60_col0, #T_7cc04_row60_col1, #T_7cc04_row60_col2, #T_7cc04_row61_col0, #T_7cc04_row61_col1, #T_7cc04_row61_col2, #T_7cc04_row62_col0, #T_7cc04_row62_col1, #T_7cc04_row62_col2, #T_7cc04_row63_col0, #T_7cc04_row63_col1, #T_7cc04_row63_col2 ...
#   text-align: left;
# }
# </style>
# <table id="T_7cc04_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Code</th>
#       <th class="col_heading level0 col1" >Description</th>
#       <th class="col_heading level0 col2" >Na</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cc04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7cc04_row0_col0" class="data row0 col0" >numer_sta</td>
#       <td id="T_7cc04_row0_col1" class="data row0 col1" >ID OMM station</td>
#       <td id="T_7cc04_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7cc04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7cc04_row1_col0" class="data row1 col0" >date</td>
#       <td id="T_7cc04_row1_col1" class="data row1 col1" >Date</td>
#       <td id="T_7cc04_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7cc04_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7cc04_row2_col0" class="data row2 col0" >pmer</td>
#       <td id="T_7cc04_row2_col1" class="data row2 col1" >Pression au niveau mer</td>
#       <td id="T_7cc04_row2_col2" class="data row2 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_7cc04_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7cc04_row3_col0" class="data row3 col0" >tend</td>
#       <td id="T_7cc04_row3_col1" class="data row3 col1" >Variation de pression en 3 heures</td>
#       <td id="T_7cc04_row3_col2" class="data row3 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7cc04_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7cc04_row4_col0" class="data row4 col0" >cod_tend</td>
#       <td id="T_7cc04_row4_col1" class="data row4 col1" >Type de tendance barométrique</td>
#       <td id="T_7cc04_row4_col2" class="data row4 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7cc04_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7cc04_row5_col0" class="data row5 col0" >dd</td>
#       <td id="T_7cc04_row5_col1" class="data row5 col1" >Direction du vent moyen 10 mn</td>
#       <td id="T_7cc04_row5_col2" class="data row5 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7cc04_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7cc04_row6_col0" class="data row6 col0" >ff</td>
#       <td id="T_7cc04_row6_col1" class="data row6 col1" >Vitesse du vent moyen 10 mn</td>
#       <td id="T_7cc04_row6_col2" class="data row6 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7cc04_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7cc04_row7_col0" class="data row7 col0" >t</td>
#       <td id="T_7cc04_row7_col1" class="data row7 col1" >Température</td>
#       <td id="T_7cc04_row7_col2" class="data row7 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_7cc04_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7cc04_row8_col
# Shape is :  (29165, 81)

# %% [markdown]
# ## Step 4 - Prepare dataset
# ### 4.1 - Keep only certain columns

# %%
columns_used=['date','pmer','tend','cod_tend','dd','ff','td','u','ww','pres','rafper','per','rr1','rr3','tc']

# ---- Drop unused columns

to_drop = df.columns.difference(columns_used)
df.drop( to_drop, axis=1, inplace=True)

# ---- Show all of that

subtitle('Our selected columns :')
display(df.head(20))

subtitle('Few statistics :')
display(df.describe().style.format('{:.2f}'))

# ---- 'per' column is constant, we can drop it

df.drop(['per'],axis=1,inplace=True)
# Out:
# <br>**Our selected columns :**
#                          date      pmer   tend  cod_tend     dd    ff      td  \
# 0   2015-06-12T17:00:00+02:00  101050.0 -230.0       6.0  140.0   3.6  286.25
# 1   2015-06-05T17:00:00+02:00  101590.0 -220.0       8.0  190.0   3.9  286.95
# 2   2015-06-15T11:00:00+02:00  101420.0   90.0       1.0  270.0   1.5  286.85
# 3   2015-06-15T14:00:00+02:00  101430.0   20.0       1.0   10.0   2.5  286.45
# 4   2015-06-20T05:00:00+02:00  102030.0    0.0       4.0   50.0   0.7  282.95
# 5   2015-06-22T05:00:00+02:00  101680.0 -120.0       6.0  180.0   0.7  286.15
# 6   2015-06-23T02:00:00+02:00  101270.0  150.0       2.0   20.0   4.5  282.95
# 7   2015-06-25T14:00:00+02:00  102180.0  -40.0       8.0   10.0   2.3  283.25
# 8   2015-07-05T20:00:00+02:00  101410.0   50.0       3.0  190.0   8.3  288.05
# 9   2015-05-14T17:00:00+02:00  101070.0 -150.0       6.0   20.0   6.2  284.95
# 10  2015-03-16T22:00:00+01:00  102150.0   40.0       1.0   50.0   1.7  275.05
# 11  2015-03-26T01:00:00+01:00  101140.0  100.0       1.0  330.0   5.9  275.45
# 12  2015-04-03T17:00:00+02:00  101690.0 -250.0       7.0  340.0   3.5  278.15
# 13  2015-04-05T20:00:00+02:00  101850.0  140.0       3.0   10.0   7.8  268.45
# 14  2014-10-22T17:00:00+02:00  102670.0  -70.0       8.0   20.0   4.6  275.35
# 15  2015-02-08T16:00:00+01:00  102570.0   20.0       3.0  350.0  12.3  271.55
# 16  2015-02-11T07:00:00+01:00  102670.0  -10.0       7.0  290.0   2.0  267.55
# 17  2015-02-07T04:00:00+01:00  101900.0  160.0       1.0  310.0   2.0  268.65
# 18  2015-02-13T04:00:00+01:00  102140.0  -50.0       8.0  140.0   2.1  273.55
# 19  2015-02-16T19:00:00+01:00  102060.0  100.0       3.0   20.0   3.2  275.65
#
#        u    ww     pres  rafper   per  rr1  rr3    tc
# 0   50.0   2.0  98330.0     5.1 -10.0  0.0 -0.1  24.2
# 1   32.0   3.0  98930.0     9.9 -10.0  0.0  0.0  32.6
# 2   64.0   3.0  98660.0     4.5 -10.0  0.0  0.0  20.8
# 3   55.0   1.0  98680.0     5.1 -10.0  0.0  0.0  22.8
# 4   82.0   2.0  99170.0     2.4 -10.0  0.0  0.0  12.8
# 5   80.0   1.0  98870.0     4.7 -10.0  0.0 -0.1  16.5
# 6   54.0   0.0  98490.0    10.2 -10.0  0.0  0.0  19.3
# 7   38.0   1.0  99430.0     7.5 -10.0  0.0  0.0  25.5
# 8   33.0   3.0  98760.0    13.4 -10.0  0.0  0.0  33.4
# 9   60.0   3.0  98300.0    11.1 -10.0  0.0  0.0  19.8
# 10  62.0   1.0  99240.0     4.6 -10.0  0.0  0.0   8.8
# 11  82.0   1.0  98220.0     8.1 -10.0  0.0  0.0   5.1
# 12  55.0   1.0  98850.0     6.4 -10.0  0.0  0.0  13.9
# 13  38.0   1.0  98950.0    13.5 -10.0  0.0  0.0   8.9
# 14  55.0   1.0  99770.0     7.2 -10.0  0.0  0.0  10.9
# 15  68.0   0.0  99590.0    19.9 -10.0  0.0  0.0   3.8
# 16  88.0  10.0  99610.0     3.3 -10.0  0.0  0.0  -3.9
# 17  74.0   2.0  98900.0     3.2 -10.0  0.0  0.0  -0.4
# 18  74.0   0.0  99190.0     4.9 -10.0  0.0  0.0   4.6
# 19  88.0   1.0  99110.0     5.1 -10.0  0.0  0.0   4.3
# <br>**Few statistics :**
# <style type="text/css">
# </style>
# <table id="T_b3d1f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pmer</th>
#       <th class="col_heading level0 col1" >tend</th>
#       <th class="col_heading level0 col2" >cod_tend</th>
#       <th class="col_heading level0 col3" >dd</th>
#       <th class="col_heading level0 col4" >ff</th>
#       <th class="col_heading level0 col5" >td</th>
#       <th class="col_heading level0 col6" >u</th>
#       <th class="col_heading level0 col7" >ww</th>
#       <th class="col_heading level0 col8" >pres</th>
#       <th class="col_heading level0 col9" >rafper</th>
#       <th class="col_heading level0 col10" >per</th>
#       <th class="col_heading level0 col11" >rr1</th>
#       <th class="col_heading level0 col12" >rr3</th>
#       <th class="col_heading level0 col13" >tc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3d1f_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_b3d1f_row0_col0" class="data row0 col0" >29148.00</td>
#       <td id="T_b3d1f_row0_col1" class="data row0 col1" >29163.00</td>
#       <td id="T_b3d1f_row0_col2" class="data row0 col2" >29163.00</td>
#       <td id="T_b3d1f_row0_col3" class="data row0 col3" >29162.00</td>
#       <td id="T_b3d1f_row0_col4" class="data row0 col4" >29163.00</td>
#       <td id="T_b3d1f_row0_col5" class="data row0 col5" >29148.00</td>
#       <td id="T_b3d1f_row0_col6" class="data row0 col6" >29148.00</td>
#       <td id="T_b3d1f_row0_col7" class="data row0 col7" >29164.00</td>
#       <td id="T_b3d1f_row0_col8" class="data row0 col8" >29165.00</td>
#       <td id="T_b3d1f_row0_col9" class="data row0 col9" >29156.00</td>
#       <td id="T_b3d1f_row0_col10" class="data row0 col10" >29157.00</td>
#       <td id="T_b3d1f_row0_col11" class="data row0 col11" >29070.00</td>
#       <td id="T_b3d1f_row0_col12" class="data row0 col12" >29092.00</td>
#       <td id="T_b3d1f_row0_col13" class="data row0 col13" >29151.00</td>
#     </tr>
#     <tr>
#       <th id="T_b3d1f_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_b3d1f_row1_col0" class="data row1 col0" >101753.55</td>
#       <td id="T_b3d1f_row1_col1" class="data row1 col1" >0.26</td>
#       <td id="T_b3d1f_row1_col2" class="data row1 col2" >4.31</td>
#       <td id="T_b3d1f_row1_col3" class="data row1 col3" >204.09</td>
#       <td id="T_b3d1f_row1_col4" class="data row1 col4" >3.40</td>
#       <td id="T_b3d1f_row1_col5" class="data row1 col5" >280.03</td>
#       <td id="T_b3d1f_row1_col6" class="data row1 col6" >71.02</td>
#       <td id="T_b3d1f_row1_col7" class="data row1 col7" >10.11</td>
#       <td id="T_b3d1f_row1_col8" class="data row1 col8" >98894.60</td>
#       <td id="T_b3d1f_row1_col9" class="data row1 col9" >6.30</td>
#       <td id="T_b3d1f_row1_col10" class="data row1 col10" >-10.00</td>
#       <td id="T_b3d1f_row1_col11" class="data row1 col11" >0.09</td>
#       <td id="T_b3d1f_row1_col12" class="data row1 col12" >0.28</td>
#       <td id="T_b3d1f_row1_col13" class="data row1 col13" >12.69</td>
#     </tr>
#     <tr>
#       <th id="T_b3d1f_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_b3d1f_row2_col0" class="data row2 col0" >798.09</td>
#       <td id="T_b3d1f_row2_col1" class="data row2 col1" >111.44</td>
#       <td id="T_b3d1f_row2_col2" class="data row2 col2" >2.72</td>
#       <td id="T_b3d1f_row2_col3" class="data row2 col3" >115.42</td>
#       <td id="T_b3d1f_row2_col4" class="data row2 col4" >2.47</td>
#       <td id="T_b3d1f_row2_col5" class="data row2 col5" >5.86</td>
#       <td id="T_b3d1f_row2_col6" class="data row2 col6" >18.28</td>
#       <td id="T_b3d1f_row2_col7" class="data row2 col7" >19.40</td>
#       <td id="T_b3d1f_row2_col8" class="data row2 col8" >761.59</td>
#       <td id="T_b3d1f_row2_col9" class="data row2 col9" >3.85</td>
#       <td id="T_b3d1f_row2_col10" class="data row2 col10" >0.00</td>
#       <td id="T_b3d1f_row2_col11" class="data row2 col11" >0.61</td>
#       <td id="T_b3d1f_row2_col12" class="data row2 col12" >1.41</td>
#       <td id="T_b3d1f_row2_col13" class="data row2 col13" >8.15</td>
#     </tr>
#     <tr>
#       <th id="T_b3d1f_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_b3d1f_row3_col0" class="data row3 col0" >97960.00</td>
#       <td id="T_b3d1f_row3_col1" class="data row3 col1" >-750.00</td>
#       <td id="T_b3d1f_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_b3d1f_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_b3d1f_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_b3d1f_row3_col5" class="data row3 col5" >249.25</td>
#       <td id="T_b3d1f_row3_col6" class="data row3 col6" >2.00</td>
#       <td id="T_b3d1f_row3_col7" class="data row3 col7" >0.00</td>
#       <td id="T_b3d1f_row3_col8" class="data row3 col8" >95170.00</td>
#       <td id="T_b3d1f_row3_col9" class="data row3 col9" >0.00</td>
#       <td id="T_b3d1f_row3_col10" class="data row3 col10" >-10.00</td>
#       <td id="T_b3d1f_row3_col11" class="data row3 col11" >-0.10</td>
#       <td id="T_b3d1f_row3_col12" class="data row3 col12" >-0.10</td>
#       <td id="T_b3d1f_row3_col13" class="data row3 col13" >-12.10</td>
#     </tr>
#     <tr>
#       <th id="T_b3d1f_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_b3d1f_row4_col0" class="data row4 col0" >101300.00</td>
#       <td id="T_b3d1f_row4_col1" class="data row4 col1" >-70.00</td>
#       <td id="T_b3d1f_row4_col2" class="data row4 col2" >2.00</td>
#       <td id="T_b3d1f_row4_col3" class="data row4 col3" >130.00</td>
#       <td id="T_b3d1f_row4_col4" class="data row4 col4" >1.50</td>
#       <td id="T_b3d1f_row4_col5" class="data row4 col5" >275.83</td>
#       <td id="T_b3d1f_row4_col6" class="data row4 col6" >58.00</td>
#       <td id="T_b3d1f_row4_col7" class="data row4 col7" >2.00</td>
#       <td id="T_b3d1f_row4_col8" class="data row4 col8" >98480.00</td>
#       <td id="T_b3d1f_row4_col9" class="data row4 col9" >3.60</td>
#       <td id="T_b3d1f_row4_col10" class="data row4 col10" >-10.00</td>
#       <td id="T_b3d1f_row4_col11" class="data row4 col11" >0.00</td>
#       <td id="T_b3d1f_row4_col12" class="data row4 col12" >0.00</td>
#       <td id="T_b3d1f_row4_col13" class="data row4 col13" >6.60</td>
#     </tr>
#     <tr>
#       <th id="T_b3d1f_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_b3d1f_row5_col0" class="data row5 col0" >101740.00</td>
#       <td id="T_b3d1f_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_b3d1f_row5_col2" class="data row5 col2" >3.00</td>
#       <td id="T_b3d1f_row5_col3" class="data row5 col3" >190.00</td>
#       <td id="T_b3d1f_row5_col4" class="data row5 col4" >2.90</td>
#       <td id="T_b3d1f_row5_col5" class="data row5 col5" >280.25</td>
#       <td id="T_b3d1f_row5_col6" class="data row5 col6" >74.00</td>
#       <td id="T_b3d1f_row5_col7" class="data row5 col7" >2.00</td>
#       <td id="T_b3d1f_row5_col8" class="data row5 col8" >98920.00</td>
#       <td id="T_b3d1f_row5_col9" class="data row5 col9" >5.30</td>
#       <td id="T_b3d1f_row5_col10" class="data row5 col10" >-10.00</td>
#       <td id="T_b3d1f_row5_col11" class="data row5 col11" >0.00</td>
#       <td id="T_b3d1f_row5_col12" class="data row5 col12" >0.00</td>
#       <td id="T_b3d1f_row5_col13" class="data row5 col13" >12.50</td>
#     </tr>
#     <tr>
#       <th id="T_b3d1f_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_b3d1f_row6_col0" class="data row6 col0" >102240.00</td>
#       <td id="T_b3d1f_row6_col1" class="data row6 col1" >70.00</td>
#       <td id="T_b3d1f_row6_col2" class="data row6 col2" >7.00</td>
#       <td id="T_b3d1f_row6_col3" class="data row6 col3" >330.00</td>
#       <td id="T_b3d1f_row6_col4" class="data row6 col4" >4.60</td>
#       <td id="T_b3d1f_row6_col5" class="data row6 col5" >284.55</td>
#       <td id="T_b3d1f_row6_col6" class="data row6 col6" >86.00</td>
#       <td id="T_b3d1f_row6_col7" class="data row6 col7" >3.00</td>
#       <td id="T_b3d1f_row6_col8" class="data row6 col8" >99360.00</td>
#       <td id="T_b3

# %% [markdown]
# ### 4.2 - Cleanup dataset
# Let's sort it and cook up some NaN values

# %%
# ---- First of all, we have to sort on the date

df.sort_values(['date'],  inplace=True)
df.reset_index(drop=True, inplace=True)

# ---- Before : Lines with NaN

na_rows=df.isna().any(axis=1)
subtitle('Before :')
display( df[na_rows].head(10) )

# ---- Nice interpolation for plugging holes

df.interpolate(inplace=True)

# ---- After

subtitle('After :')
display(df[na_rows].head(10))
# Out:
# <br>**Before :**
#                            date      pmer   tend  cod_tend     dd   ff  \
# 396   2010-02-19T16:00:00+01:00   99760.0  180.0       3.0  330.0  4.6
# 434   2010-02-24T10:00:00+01:00  100310.0   60.0       1.0    NaN  NaN
# 477   2010-03-01T19:00:00+01:00  101400.0    NaN       NaN  340.0  2.6
# 734   2010-04-03T02:00:00+02:00  101550.0   50.0       0.0  190.0  7.7
# 1061  2010-05-13T23:00:00+02:00       NaN   60.0       2.0  330.0  4.6
# 1063  2010-05-14T05:00:00+02:00       NaN  -50.0       5.0  350.0  4.1
# 1064  2010-05-14T08:00:00+02:00       NaN    0.0       5.0  350.0  4.6
# 2268  2010-10-11T20:00:00+02:00       NaN  150.0       2.0   10.0  1.0
# 2269  2010-10-11T23:00:00+02:00       NaN  130.0       3.0   80.0  1.0
# 2270  2010-10-12T02:00:00+02:00       NaN   70.0       1.0    0.0  0.0
#
#           td     u    ww     pres  rafper  rr1  rr3    tc
# 396   275.85  79.0  21.0  96890.0     NaN  0.0  1.0   6.1
# 434   279.25  77.0   2.0  97470.0     NaN  0.2  0.2   9.9
# 477   275.45  61.0   2.0  98520.0     5.7  0.0  NaN   9.4
# 734   277.55  64.0   2.0  98680.0    12.3  NaN  NaN  10.9
# 1061     NaN   NaN   2.0  98220.0     7.7  0.0  0.0   9.9
# 1063     NaN   NaN   2.0  98110.0     7.2  0.0  0.0   8.1
# 1064     NaN   NaN   2.0  98110.0     6.7  0.0  0.0   8.1
# 2268     NaN   NaN   2.0  98060.0     3.1  NaN  NaN   NaN
# 2269     NaN   NaN   2.0  98190.0     2.6  NaN  NaN   NaN
# 2270     NaN   NaN   2.0  98260.0     1.5  NaN  NaN   NaN
# <br>**After :**
#                            date           pmer   tend  cod_tend     dd    ff  \
# 396   2010-02-19T16:00:00+01:00   99760.000000  180.0       3.0  330.0  4.60
# 434   2010-02-24T10:00:00+01:00  100310.000000   60.0       1.0  170.0  4.15
# 477   2010-03-01T19:00:00+01:00  101400.000000  195.0       4.0  340.0  2.60
# 734   2010-04-03T02:00:00+02:00  101550.000000   50.0       0.0  190.0  7.70
# 1061  2010-05-13T23:00:00+02:00  101020.000000   60.0       2.0  330.0  4.60
# 1063  2010-05-14T05:00:00+02:00  101040.000000  -50.0       5.0  350.0  4.10
# 1064  2010-05-14T08:00:00+02:00  101040.000000    0.0       5.0  350.0  4.60
# 2268  2010-10-11T20:00:00+02:00  100786.666667  150.0       2.0   10.0  1.00
# 2269  2010-10-11T23:00:00+02:00  100863.333333  130.0       3.0   80.0  1.00
# 2270  2010-10-12T02:00:00+02:00  100940.000000   70.0       1.0    0.0  0.00
#
#           td          u    ww     pres  rafper  rr1  rr3     tc
# 396   275.85  79.000000  21.0  96890.0    8.25  0.0  1.0   6.10
# 434   279.25  77.000000   2.0  97470.0    6.65  0.2  0.2   9.90
# 477   275.45  61.000000   2.0  98520.0    5.70  0.0  0.5   9.40
# 734   277.55  64.000000   2.0  98680.0   12.30  0.0  0.0  10.90
# 1061  281.25  86.500000   2.0  98220.0    7.70  0.0  0.0   9.90
# 1063  279.15  80.666667   2.0  98110.0    7.20  0.0  0.0   8.10
# 1064  279.35  79.333333   2.0  98110.0    6.70  0.0  0.0   8.10
# 2268  284.75  83.333333   2.0  98060.0    3.10  0.0  0.0  14.45
# 2269  284.45  84.666667   2.0  98190.0    2.60  0.0  0.0  13.90
# 2270  284.15  86.000000   2.0  98260.0    1.50  0.0  0.0  13.35

# %% [markdown]
# ## Step 5 - About our enhanced dataset
# ### 5.1 - Summarize it

# %%
# ---- Count the na values by columns
dataset_na    = df.isna().sum().tolist()
dataset_cols  = df.columns.tolist()
dataset_desc  = [ code2desc[c] for c in dataset_cols ]

# ---- Show all of that
df_desc=pd.DataFrame({'Columns':dataset_cols, 'Description':dataset_desc, 'Na':dataset_na})
subtitle('Dataset columns :')
display(df_desc.style.set_properties(**{'text-align': 'left'}))

subtitle('Have a look :')
display(df.tail(20))
print('Shape is : ', df.shape)
# Out:
# <br>**Dataset columns :**
# <style type="text/css">
# #T_5521f_row0_col0, #T_5521f_row0_col1, #T_5521f_row0_col2, #T_5521f_row1_col0, #T_5521f_row1_col1, #T_5521f_row1_col2, #T_5521f_row2_col0, #T_5521f_row2_col1, #T_5521f_row2_col2, #T_5521f_row3_col0, #T_5521f_row3_col1, #T_5521f_row3_col2, #T_5521f_row4_col0, #T_5521f_row4_col1, #T_5521f_row4_col2, #T_5521f_row5_col0, #T_5521f_row5_col1, #T_5521f_row5_col2, #T_5521f_row6_col0, #T_5521f_row6_col1, #T_5521f_row6_col2, #T_5521f_row7_col0, #T_5521f_row7_col1, #T_5521f_row7_col2, #T_5521f_row8_col0, #T_5521f_row8_col1, #T_5521f_row8_col2, #T_5521f_row9_col0, #T_5521f_row9_col1, #T_5521f_row9_col2, #T_5521f_row10_col0, #T_5521f_row10_col1, #T_5521f_row10_col2, #T_5521f_row11_col0, #T_5521f_row11_col1, #T_5521f_row11_col2, #T_5521f_row12_col0, #T_5521f_row12_col1, #T_5521f_row12_col2, #T_5521f_row13_col0, #T_5521f_row13_col1, #T_5521f_row13_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_5521f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Columns</th>
#       <th class="col_heading level0 col1" >Description</th>
#       <th class="col_heading level0 col2" >Na</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5521f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5521f_row0_col0" class="data row0 col0" >date</td>
#       <td id="T_5521f_row0_col1" class="data row0 col1" >Date</td>
#       <td id="T_5521f_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5521f_row1_col0" class="data row1 col0" >pmer</td>
#       <td id="T_5521f_row1_col1" class="data row1 col1" >Pression au niveau mer</td>
#       <td id="T_5521f_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5521f_row2_col0" class="data row2 col0" >tend</td>
#       <td id="T_5521f_row2_col1" class="data row2 col1" >Variation de pression en 3 heures</td>
#       <td id="T_5521f_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5521f_row3_col0" class="data row3 col0" >cod_tend</td>
#       <td id="T_5521f_row3_col1" class="data row3 col1" >Type de tendance barométrique</td>
#       <td id="T_5521f_row3_col2" class="data row3 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5521f_row4_col0" class="data row4 col0" >dd</td>
#       <td id="T_5521f_row4_col1" class="data row4 col1" >Direction du vent moyen 10 mn</td>
#       <td id="T_5521f_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5521f_row5_col0" class="data row5 col0" >ff</td>
#       <td id="T_5521f_row5_col1" class="data row5 col1" >Vitesse du vent moyen 10 mn</td>
#       <td id="T_5521f_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5521f_row6_col0" class="data row6 col0" >td</td>
#       <td id="T_5521f_row6_col1" class="data row6 col1" >Point de rosée</td>
#       <td id="T_5521f_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5521f_row7_col0" class="data row7 col0" >u</td>
#       <td id="T_5521f_row7_col1" class="data row7 col1" >Humidité</td>
#       <td id="T_5521f_row7_col2" class="data row7 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5521f_row8_col0" class="data row8 col0" >ww</td>
#       <td id="T_5521f_row8_col1" class="data row8 col1" >Temps présent</td>
#       <td id="T_5521f_row8_col2" class="data row8 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5521f_row9_col0" class="data row9 col0" >pres</td>
#       <td id="T_5521f_row9_col1" class="data row9 col1" >Pression station</td>
#       <td id="T_5521f_row9_col2" class="data row9 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5521f_row10_col0" class="data row10 col0" >rafper</td>
#       <td id="T_5521f_row10_col1" class="data row10 col1" >Rafales sur une période</td>
#       <td id="T_5521f_row10_col2" class="data row10 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5521f_row11_col0" class="data row11 col0" >rr1</td>
#       <td id="T_5521f_row11_col1" class="data row11 col1" >Précipitations dans la dernière heure</td>
#       <td id="T_5521f_row11_col2" class="data row11 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5521f_row12_col0" class="data row12 col0" >rr3</td>
#       <td id="T_5521f_row12_col1" class="data row12 col1" >Précipitations dans les 3 dernières heures</td>
#       <td id="T_5521f_row12_col2" class="data row12 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5521f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5521f_row13_col0" class="data row13 col0" >tc</td>
#       <td id="T_5521f_row13_col1" class="data row13 col1" >Température (°C)</td>
#       <td id="T_5521f_row13_col2" class="data row13 col2" >0</td>
#     </tr>
#   </tbody>
# </table>
# <br>**Have a look :**
#                             date      pmer   tend  cod_tend     dd    ff  \
# 29145  2020-02-24T13:00:00+01:00  102380.0 -220.0       8.0  120.0   1.6
# 29146  2020-02-24T16:00:00+01:00  101990.0 -350.0       6.0  110.0   1.6
# 29147  2020-02-24T19:00:00+01:00  101800.0 -220.0       6.0  150.0   2.9
# 29148  2020-02-24T22:00:00+01:00  101740.0  -80.0       6.0  170.0   1.8
# 29149  2020-02-25T01:00:00+01:00  101640.0 -150.0       8.0  170.0   2.5
# 29150  2020-02-25T04:00:00+01:00  101450.0 -200.0       6.0  150.0   3.7
# 29151  2020-02-25T07:00:00+01:00  101530.0   60.0       3.0   30.0   4.0
# 29152  2020-02-25T10:00:00+01:00  101490.0  -20.0       8.0  200.0   1.8
# 29153  2020-02-25T13:00:00+01:00  101330.0 -140.0       8.0  150.0   3.8
# 29154  2020-02-25T16:00:00+01:00  100990.0 -290.0       6.0  140.0   4.4
# 29155  2020-02-25T19:00:00+01:00  100910.0  -90.0       5.0  260.0   4.3
# 29156  2020-02-25T22:00:00+01:00  100980.0   60.0       3.0  280.0   8.0
# 29157  2020-02-26T01:00:00+01:00  101040.0   30.0       2.0  230.0   2.8
# 29158  2020-02-26T04:00:00+01:00  101060.0  -10.0       8.0  230.0   3.0
# 29159  2020-02-26T07:00:00+01:00  100940.0 -110.0       6.0  210.0   3.3
# 29160  2020-02-26T10:00:00+01:00  101100.0  160.0       3.0  230.0   6.8
# 29161  2020-02-26T13:00:00+01:00  101200.0  100.0       3.0  310.0  10.3
# 29162  2020-02-26T16:00:00+01:00  101290.0  100.0       3.0  310.0   8.9
# 29163  2020-02-26T19:00:00+01:00  101550.0  230.0       2.0  300.0   2.8
# 29164  2020-02-26T22:00:00+01:00  101780.0  200.0       2.0   50.0   3.2
#
#            td     u    ww     pres  rafper  rr1  rr3    tc
# 29145  281.15  59.0   0.0  99540.0     3.7  0.0  0.0  16.0
# 29146  281.55  50.0   3.0  99190.0     3.3  0.0  0.0  19.1
# 29147  280.05  55.0   3.0  98970.0     4.1  0.0  0.0  15.9
# 29148  280.35  67.0   2.0  98890.0     4.3  0.0  0.0  13.2
# 29149  278.85  83.0   2.0  98740.0     4.7  0.0  0.0   8.4
# 29150  277.75  87.0   2.0  98540.0     4.8  0.0  0.0   6.6
# 29151  276.95  92.0   3.0  98600.0     6.1  0.0  0.0   5.0
# 29152  277.55  87.0   3.0  98580.0     5.5  0.0  0.0   6.4
# 29153  278.95  85.0  21.0  98440.0     7.1  0.6  2.0   8.2
# 29154  279.55  69.0   3.0  98150.0     7.2  0.0  0.0  11.9
# 29155  278.95  69.0  25.0  98060.0     8.4 -0.1 -0.1  11.3
# 29156  273.65  51.0   1.0  98120.0    11.3  0.0  0.0  10.2
# 29157  275.65  69.0  25.0  98150.0    10.7 -0.1 -0.1   7.8
# 29158  275.85  86.0  25.0  98140.0    13.6  0.4  1.8   4.8
# 29159  274.85  78.0  21.0  98030.0     7.4 -0.1 -0.1   5.2
# 29160  274.45  74.0   1.0  98190.0    10.0  0.0  0.0   5.6
# 29161  270.55  52.0   1.0  98290.0    19.5  0.0 -0.1   6.6
# 29162  270.55  47.0   1.0  98390.0    14.3  0.0  0.0   8.0
# 29163  272.05  64.0   1.0  98620.0     7.4  0.0  0.0   5.2
# 29164  274.05  84.0   1.0  98820.0     8.2  0.0  0.0   3.3
# Shape is :  (29165, 14)

# %% [markdown]
# ### 5.2 - Have a look (1 month)

# %%
i=random.randint(0,len(df)-240)
df.iloc[i:i+240].plot(subplots=True, fontsize=12, figsize=(16,20))
plt.show()

# %% [markdown]
# ## Step 6 - Save it

# %%
os.makedirs(output_dir,   mode=0o750, exist_ok=True)

filedata = f'{output_dir}/{dataset_filename}'
filedesc = f'{output_dir}/{description_filename}'

df.to_csv(filedata, sep=';', index=False)
size=os.path.getsize(filedata)/(1024*1024)
print(f'Dataset saved. ({size:0.1f} Mo)')

with open(filedesc, 'w', encoding='utf-8') as f:
    json.dump(code2desc, f, indent=4)
print('Synop description saved.')
# Out:
# Dataset saved. (3.0 Mo)
# Synop description saved.
